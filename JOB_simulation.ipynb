# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df1=pd.read_csv(r'C:\Users\Admin\Downloads\price_data (1).csv')
df2= pd.read_csv(r'C:\Users\Admin\Downloads\client_data (1).csv') 

df1.head(5)
# Out:
#                                  id  price_date  price_off_peak_var  \
# 0  038af19179925da21a25619c5a24b745  2015-01-01            0.151367
# 1  038af19179925da21a25619c5a24b745  2015-02-01            0.151367
# 2  038af19179925da21a25619c5a24b745  2015-03-01            0.151367
# 3  038af19179925da21a25619c5a24b745  2015-04-01            0.149626
# 4  038af19179925da21a25619c5a24b745  2015-05-01            0.149626
#
#    price_peak_var  price_mid_peak_var  price_off_peak_fix  price_peak_fix  \
# 0             0.0                 0.0           44.266931             0.0
# 1             0.0                 0.0           44.266931             0.0
# 2             0.0                 0.0           44.266931             0.0
# 3             0.0                 0.0           44.266931             0.0
# 4             0.0                 0.0           44.266931             0.0
#
#    price_mid_peak_fix
# 0                 0.0
# 1                 0.0
# 2                 0.0
# ...

# %%
df2.head(5)
# Out:
#                                  id                     channel_sales  \
# 0  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1  d29c2c54acc38ff3c0614d0a653813dd                           MISSING
# 2  764c75f661154dac3a6c254cd082ea7d  foosdfpfkusacimwkcsosbicdxkicaua
# 3  bba03439a292a1e166f80264c16191cb  lmkebamcaaclubfxadlmueccxoimlema
# 4  149d57cf92fc41cf94415803a877cb4b                           MISSING
#
#    cons_12m  cons_gas_12m  cons_last_month  date_activ    date_end  \
# 0         0         54946                0  2013-06-15  2016-06-15
# 1      4660             0                0  2009-08-21  2016-08-30
# 2       544             0                0  2010-04-16  2016-04-16
# 3      1584             0                0  2010-03-30  2016-03-30
# 4      4425             0              526  2010-01-13  2016-03-07
#
#   date_modif_prod date_renewal  forecast_cons_12m  ...  has_gas  imp_cons  \
# ...

# %%
print("Data Types for Customer Data:")
print(df1.dtypes)
print("\nData Types for Pricing Data:")
print(df2.dtypes)
# Out:
# Data Types for Customer Data:
# id                     object
# price_date             object
# price_off_peak_var    float64
# price_peak_var        float64
# price_mid_peak_var    float64
# price_off_peak_fix    float64
# price_peak_fix        float64
# price_mid_peak_fix    float64
# dtype: object
#
# Data Types for Pricing Data:
# id                                 object
# channel_sales                      object
# cons_12m                            int64
# cons_gas_12m                        int64
# cons_last_month                     int64
# date_activ                         object
# date_end                           object
# date_modif_prod                    object
# date_renewal                       object
# forecast_cons_12m                 float64
# forecast_cons_year                  int64
# forecast_discount_energy          float64
# forecast_meter_rent_12m           float64
# forecast_price_energy_off_peak    float64
# forecast_price_energy_peak        float64
# ...

# %%
# 2. Descriptive Statistics of the Dataset
print("\nDescriptive Statistics for Customer Data:")
print(df1.describe())
print("\nDescriptive Statistics for Pricing Data:")
print(df2.describe())
# Out:
# Descriptive Statistics for Customer Data:
#        price_off_peak_var  price_peak_var  price_mid_peak_var  \
# count       193002.000000   193002.000000       193002.000000
# mean             0.141027        0.054630            0.030496
# std              0.025032        0.049924            0.036298
# min              0.000000        0.000000            0.000000
# 25%              0.125976        0.000000            0.000000
# 50%              0.146033        0.085483            0.000000
# 75%              0.151635        0.101673            0.072558
# max              0.280700        0.229788            0.114102
#
#        price_off_peak_fix  price_peak_fix  price_mid_peak_fix
# count       193002.000000   193002.000000       193002.000000
# mean            43.334477       10.622875            6.409984
# std              5.410297       12.841895            7.773592
# min              0.000000        0.000000            0.000000
# ...

# %%
# 3. Distributions of Key Columns
# Visualize numerical columns for Customer Data (usage, pricing, etc.)
numerical_columns_customer = ['price_off_peak_var', 'price_peak_var', 'price_mid_peak_var', 
                              'price_off_peak_fix', 'price_peak_fix', 'price_mid_peak_fix']

# Plot histograms for numerical columns in Customer Data
for col in numerical_columns_customer:
    plt.figure(figsize=(8, 6))
    sns.histplot(df1[col], kde=True)
    plt.title(f'Distribution of {col} in Customer Data')
    plt.show()

# Visualize numerical columns for Pricing Data
numerical_columns_pricing = ['cons_12m', 'cons_gas_12m', 'cons_last_month', 'forecast_cons_12m',
                            'forecast_cons_year', 'forecast_discount_energy', 'forecast_meter_rent_12m',
                            'forecast_price_energy_off_peak', 'forecast_price_energy_peak',
                            'forecast_price_pow_off_peak', 'imp_cons', 'margin_gross_pow_ele',
                            'margin_net_pow_ele', 'net_margin', 'pow_max', 'churn']

# Plot histograms for numerical columns in Pricing Data
for col in numerical_columns_pricing:
    plt.figure(figsize=(8, 6))
    sns.histplot(df2[col], kde=True)
    plt.title(f'Distribution of {col} in Pricing Data')
    plt.show()

# Visualizing categorical columns (Customer Data)
categorical_columns_customer = ['id', 'price_date']

# Plotting countplots for categorical data in Customer Data
for col in categorical_columns_customer:
    plt.figure(figsize=(8, 6))
    sns.countplot(x=df1[col])
    plt.title(f'Distribution of {col} in Customer Data')
    plt.xticks(rotation=45)
    plt.show()

# Visualizing categorical columns (Pricing Data)
categorical_columns_pricing = ['id', 'channel_sales', 'has_gas', 'origin_up']

# Plotting countplots for categorical data in Pricing Data
for col in categorical_columns_pricing:
    plt.figure(figsize=(8, 6))
    sns.countplot(x=df2[col])
    plt.title(f'Distribution of {col} in Pricing Data')
    plt.xticks(rotation=45)
    plt.show()

# Visualizing Churn Distribution (Categorical)
plt.figure(figsize=(8, 6))
sns.countplot(x=pricing_data['churn'])
plt.title('Churn Distribution')
plt.show()
